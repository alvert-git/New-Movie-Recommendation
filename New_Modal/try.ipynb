# %%
import pandas as pd

# %%
df = pd.read_csv("movies_to_db.csv")

print(df.head(1))
# Out:
#    movie_id    title                                       tagline  \
# 0    211672  Minions  Before Gru, they had a history of bad bosses
#
#                                             overview  runtime release_date  \
# 0  Minions Stuart, Kevin and Bob are recruited by...     91.0   2015-06-17
#
#      budget  price                   poster_url  \
# 0  74000000   9.99  /uploads/posters/211672.jpg
#
#                     backdrop_url                                    video_url  \
# 0  /uploads/backdrops/211672.jpg  https://www.youtube.com/watch?v=lCgtmgiII7M
#
#                                                 tags  \
# 0  minion stuart, kevin and bob are recruit by sc...
#
#                                  genres  \
# 0  Family, Animation, Adventure, Comedy
#
#                                        cast        crew
# 0  Sandra Bullock, Jon Hamm, Michael Keaton  Kyle Balda
